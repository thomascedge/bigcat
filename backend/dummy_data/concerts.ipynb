# %%
from pydantic import BaseModel, ConfigDict, BeforeValidator, Field
from enum import Enum
from datetime import datetime
from typing import Optional, Annotated

PyObjectId = Annotated[str, BeforeValidator(str)]

class ConcertStatus(Enum):
    TENTATIVE = 0
    CONFIRMED = 1
    ON_SALE = 2
    SOLD_OUT = 3
    POSTPONED = 4
    CANCELED = 5
    COMPLETED = 6

class NewConcert(BaseModel):
    id: Optional[PyObjectId] = Field(alias='_id', default=None) # primary key
    uid: str
    artist: str
    tour_name: Optional[str] 
    venue: str
    location: str
    concert_datetime: datetime
    status: Optional[ConcertStatus | int]
    update_datetime: datetime

    model_config = ConfigDict(use_enum_values=True)

# %%
import requests
from bs4 import BeautifulSoup
from uuid import uuid4
from datetime import datetime

def get_concert_data(url:str, location:str) -> list:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    m_boxes = soup.find_all('div', class_='MuiCardContent-root styles_cardContent__nFnOO styles_small__RCnB2 mui-15q2cw4')
    cap = soup.find_all(attrs={'data-testid': 'card-venue-name-0'})
    data = []

    for box, caption in zip(m_boxes, cap):
        date = box.div.find_next_sibling("div").find_all("div")[0].text.replace('•', ' ')
        date = datetime.strptime(date, '%a %b %d %I:%M %p')
        date = date.replace(year=datetime.now().year)
        data.append(NewConcert(
            uid=str(uuid4()),
            artist=box.div.span.text,
            tour_name=None,
            venue=caption.text,
            location=location,
            concert_datetime=date,
            status=ConcertStatus.CONFIRMED
        ))

    return data

# %%
concert_data = []
url_list = [('https://www.vividseats.com/geo/usa/tx/austin/concerts', 'Austin, TX, USA'),
            ('https://www.vividseats.com/geo/usa/tx/houston/concerts', 'Houston, TX, USA'),
            ('https://www.vividseats.com/geo/usa/tx/san-antonio/concerts', 'San Antonio, TX, USA'),
            ('https://www.vividseats.com/geo/usa/tx/dallas/concerts', 'Dallas, TX, USA'),
            ('https://www.vividseats.com/geo/usa/tx/el-paso/concerts', 'El Paso, TX, USA')]

for url, location in url_list:
    concert_data.extend(get_concert_data(url, location))

# %%
concert_data
# Out:
# [NewConcert(id=None, uid='d9a2cab0-89aa-4f6d-8ece-a46baa1c3fb1', artist='Tate McRae', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 16, 19, 0), status=1),
#  NewConcert(id=None, uid='7853ec15-9e9b-4273-b129-5b1eaa7cf5fe', artist='Lainey Wilson', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 18, 19, 0), status=1),
#  NewConcert(id=None, uid='09e855d9-8a46-4000-9bed-e936274c3606', artist='Lorde', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 17, 19, 0), status=1),
#  NewConcert(id=None, uid='bee75b11-d53a-4f46-9bca-282b0f6d8fab', artist='SuicideBoys', tour_name='', venue='Germania Insurance Amphitheater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 18, 30), status=1),
#  NewConcert(id=None, uid='30a68002-dc6c-48c4-950e-f707b3aeacd5', artist='Mumford and Sons', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 10, 24, 19, 30), status=1),
#  NewConcert(id=None, uid='4cca26ee-a5fc-41c4-b820-6d277d4de3d3', artist='Laufey', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 21, 19, 30), status=1),
#  NewConcert(id=None, uid='f4e23673-536f-4c4c-9fec-af4e20e09515', artist='Dom Dolla (18+ Event)', tour_name='', venue='Germania Insurance Amphitheater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 10, 31, 20, 0), status=1),
#  NewConcert(id=None, uid='a4746158-c0a5-4b0d-89a5-86da715c263e', artist='The Lumineers', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 10, 14, 19, 30), status=1),
#  NewConcert(id=None, uid='f27d1cd4-3e80-442a-85aa-98ec2a140bdc', artist='Lil Wayne', tour_name='', venue='Germania Insurance Amphitheater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 16, 20, 0), status=1),
#  NewConcert(id=None, uid='3aed9163-4d2a-4bc9-8d13-463b60c1d316', artist='Addison Rae', tour_name='', venue='Austin City Limits Live at The Moody Theater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 22, 20, 0), status=1),
#  NewConcert(id=None, uid='14f2157b-4774-4606-b391-6cd4b671d52d', artist='Jonas Brothers', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 10, 17, 19, 30), status=1),
#  NewConcert(id=None, uid='f4ebb26d-4fe0-4ce6-93f3-9270443ed2df', artist='Billy Strings', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 12, 13, 19, 30), status=1),
#  NewConcert(id=None, uid='077f3991-e353-4616-9310-878d85c0b92d', artist='Crooner and The Cowboy - Leon Bridges and Charley Crockett', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 23, 19, 0), status=1),
#  NewConcert(id=None, uid='328d1b16-cf8a-4132-b7cc-7b1154234d42', artist='Junior H', tour_name='', venue='Germania Insurance Amphitheater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1),
#  NewConcert(id=None, uid='5479201a-8ebc-4c98-a5bf-dbbf9b7b1094', artist='Alabama Shakes', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 25, 19, 0), status=1),
#  NewConcert(id=None, uid='aceecff3-643e-4389-a5b0-7a6206ef337f', artist='Turnstile', tour_name='', venue='Moody Amphitheater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 10, 14, 19, 0), status=1),
#  NewConcert(id=None, uid='17d93546-b054-46f9-a993-6b7250f6bf5e', artist='Billie Eilish', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 11, 14, 19, 0), status=1),
#  NewConcert(id=None, uid='6ceb72b9-3ded-4834-9df1-aff7fde1eb12', artist='2025 Austin City Limits Festival - Weekend One 3 Day Pass (10/3 - 10/5) (Sabrina Carpenter, Hozier, The Killers, Luke Combs, The Strokes, John Summit, Doechii)', tour_name='', venue='Zilker Park', location='Austin, TX, USA', datetime=datetime.datetime(2025, 10, 3, 10, 59), status=1),
#  NewConcert(id=None, uid='b71d1a4b-b568-40fe-9c8a-b3b2daf7c2e0', artist='Ariana Grande', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 6, 26, 19, 30), status=1),
#  NewConcert(id=None, uid='5c5e1bbe-dfc3-4f8d-905d-0da69e769fc7', artist='Benson Boone', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 19, 20, 0), status=1),
#  NewConcert(id=None, uid='4a2e9f75-4cd4-4c26-9d58-d875bf89498f', artist='Tate McRae', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 16, 19, 0), status=1),
#  NewConcert(id=None, uid='bfc20693-8ae2-49a2-911e-95aebdb76fcd', artist='Tame Impala', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 11, 6, 20, 0), status=1),
#  NewConcert(id=None, uid='912fcb9d-fc87-4199-861b-6573a1dde36f', artist='Lainey Wilson', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 18, 19, 0), status=1),
#  NewConcert(id=None, uid='3356684c-b91a-41f3-b6e6-9cf202d78628', artist='Lorde', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 17, 19, 0), status=1),
#  NewConcert(id=None, uid='93dce594-c580-46c2-84ed-b30a80b2b89a', artist='SuicideBoys', tour_name='', venue='Germania Insurance Amphitheater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 18, 30), status=1),
#  NewConcert(id=None, uid='107a8d67-79a8-4af7-974f-e679ee1e50ec', artist='Mumford and Sons', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 10, 24, 19, 30), status=1),
#  NewConcert(id=None, uid='e809fbc9-7c73-4d78-8cb0-75d30b96eb5f', artist='Lady Gaga', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 3, 8, 20, 0), status=1),
#  NewConcert(id=None, uid='83d55ea7-47c7-433d-a6fe-1743097ac2bc', artist='Laufey', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 21, 19, 30), status=1),
#  NewConcert(id=None, uid='310d473d-b8de-483a-9401-7965d66828f5', artist='Dom Dolla (18+ Event)', tour_name='', venue='Germania Insurance Amphitheater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 10, 31, 20, 0), status=1),
#  NewConcert(id=None, uid='9dc4e956-203e-4882-82da-67b9dbeb2e6f', artist='The Lumineers', tour_name='', venue='Moody Center ATX', location='Austin, TX, USA', datetime=datetime.datetime(2025, 10, 14, 19, 30), status=1),
#  NewConcert(id=None, uid='dcba4150-67df-4ca1-8279-33b816146c34', artist='The Red Clay Strays', tour_name='', venue='Moody Amphitheater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 28, 19, 0), status=1),
#  NewConcert(id=None, uid='747aabe2-7df2-48d3-84b7-0ebf9ac80583', artist='Lil Wayne', tour_name='', venue='Germania Insurance Amphitheater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 16, 20, 0), status=1),
#  NewConcert(id=None, uid='f5411087-e792-40b2-85b9-44b013b3db2f', artist='SuicideBoys', tour_name='', venue='Germania Insurance Amphitheater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 18, 30), status=1),
#  NewConcert(id=None, uid='cdb2a43b-df46-45d8-85e8-1b85739a89b7', artist='The Swell Season', tour_name='', venue='Austin City Limits Live at The Moody Theater', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='195ef676-6042-4c5c-a4da-5312040765ca', artist='Marty Stuart', tour_name='', venue='Paramount Theatre Austin', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='cb53d351-0655-411c-bc6d-d575046135b5', artist='Night Cap', tour_name='', venue='Stubbs BarBQ', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 0), status=1),
#  NewConcert(id=None, uid='e6a6dba6-13f1-4d97-9ade-ae47d23c1ed3', artist='Sullivan King (18+ Event)', tour_name='', venue='The Concourse Project', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 13, 21, 0), status=1),
#  NewConcert(id=None, uid='6701df9d-62d8-4028-9642-0674b6c79586', artist='The Castellows (18+ Event)', tour_name='', venue="Antone's - Austin", location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='b2627743-89ba-4f91-b003-36a5213eb2a3', artist='Giovannie and The Hired Guns', tour_name='', venue='Gruene Hall', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 21, 30), status=1),
#  NewConcert(id=None, uid='89de5c15-9e61-4e02-aa25-2a98e7834c46', artist='Westend', tour_name='', venue='The Concourse Project', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 21, 0), status=1),
#  NewConcert(id=None, uid='9b6a8c2b-d0a7-468b-a176-cf3782ab037d', artist='Mitchell Ferguson (18+ Event)', tour_name='', venue='Cheatham Street Warehouse', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='b86ccd19-8700-4d95-991b-db0305a83cab', artist='Aloe Blacc', tour_name='', venue='3TEN Austin City Limits Live', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 21, 0), status=1),
#  NewConcert(id=None, uid='7db17b58-e7db-493b-bf64-0aa308a6e947', artist='Samia', tour_name='', venue='Scoot Inn', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 30), status=1),
#  NewConcert(id=None, uid='1cbef9c8-3bad-4a3b-b66a-33a1054835c6', artist='Donny Edwards', tour_name='', venue='Brauntex Performing Arts Theatre', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 13, 19, 30), status=1),
#  NewConcert(id=None, uid='2061d38b-d5f4-40d3-9c04-2e0b40123b82', artist='Mehro', tour_name='', venue='Empire - Control Room', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='54f0bfb6-090c-46eb-9194-25979666efa3', artist='lluvii', tour_name='', venue='Stubbs BarBQ', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 13, 19, 0), status=1),
#  NewConcert(id=None, uid='f262467c-2da8-4497-b788-5969ac6b7ccb', artist='The Droptines', tour_name='', venue="Antone's - Austin", location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='be8781a4-3e52-44e9-8f97-1a614ff05c92', artist='Austin Symphony Orchestra - Across The Globe', tour_name='', venue='Long Center for the Performing Arts - Dell Hall', location='Austin, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='4b07f6bd-bf50-420b-abf2-fa0165ca4890', artist='Lainey Wilson', tour_name='', venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1),
#  NewConcert(id=None, uid='156a4295-dff9-441b-b3ea-1ebe0247fd7b', artist='Benson Boone', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 18, 20, 0), status=1),
#  NewConcert(id=None, uid='c4d09e68-6ef5-496c-b914-956e93d64226', artist='Lil Wayne', tour_name='', venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 18, 20, 0), status=1),
#  NewConcert(id=None, uid='767c4037-9ebb-4e87-aa76-de08fa3c29d0', artist='Houston Livestock Show and Rodeo - Cody Johnson (Concert Only, No Houston Rodeo Performance)', tour_name='', venue='NRG Stadium', location='Houston, TX, USA', datetime=datetime.datetime(2025, 3, 22, 23, 59), status=1),
#  NewConcert(id=None, uid='2de06044-4070-4732-88f0-804224cbf1b1', artist='Bring Me The Horizon', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 26, 19, 0), status=1),
#  NewConcert(id=None, uid='cbe98738-7ea4-4c94-bb6b-83fdb13132c0', artist='The Lumineers', tour_name='', venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 10, 19, 30), status=1),
#  NewConcert(id=None, uid='add60ac9-4651-4cd4-9345-1863a53c6a30', artist='SuicideBoys', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 10, 18, 30), status=1),
#  NewConcert(id=None, uid='bde85f77-78c4-42b4-aeeb-4d8503625527', artist='Ludovico Einaudi', tour_name='', venue='Smart Financial Centre', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 12, 19, 0), status=1),
#  NewConcert(id=None, uid='0e0c0441-9d47-4612-af9c-9a24840e0d1f', artist='Keith Urban', tour_name='', venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 11, 19, 0), status=1),
#  NewConcert(id=None, uid='094158a2-b140-4eba-852a-d74a3c5bf28f', artist='Pentatonix', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 12, 20, 19, 0), status=1),
#  NewConcert(id=None, uid='24ce279d-2a27-4eca-8df0-30b90b28d82c', artist='Maroon 5', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 11, 5, 20, 0), status=1),
#  NewConcert(id=None, uid='eaddc8ac-bf8f-4ebd-baea-6c8472d25969', artist='Ella Langley (Moved from House of Blues)', tour_name='', venue='713 Music Hall', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 16, 20, 0), status=1),
#  NewConcert(id=None, uid='f5857557-cf8e-410f-9afc-06828225bc1e', artist='Alice Cooper and Judas Priest', tour_name='', venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 26, 18, 45), status=1),
#  NewConcert(id=None, uid='32d7edd2-b88d-4aa6-bdfe-06d259c08586', artist='Whiskey Myers', tour_name='', venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 27, 18, 30), status=1),
#  NewConcert(id=None, uid='dd305a40-b27a-4833-9208-19dc2f13d79c', artist='For King And Country', tour_name='', venue='Smart Financial Centre', location='Houston, TX, USA', datetime=datetime.datetime(2025, 12, 6, 19, 0), status=1),
#  NewConcert(id=None, uid='c4187889-498a-4fe7-90ff-118d0051eebe', artist='Fujii Kaze', tour_name='', venue='Bayou Music Center', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 8, 20, 0), status=1),
#  NewConcert(id=None, uid='75a77170-dfca-4d3c-9266-6472588b6442', artist='Lainey Wilson', tour_name='', venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1),
#  NewConcert(id=None, uid='427b1e38-7fd9-4659-845e-8efdb6a6db2c', artist='Nine Inch Nails', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 30), status=1),
#  NewConcert(id=None, uid='8c537b4b-9972-4b28-81b1-764d120b51fe', artist='Benson Boone', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 18, 20, 0), status=1),
#  NewConcert(id=None, uid='3176fc02-2b8c-43c9-9b11-9d64848a75a4', artist='NBA YoungBoy', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 28, 19, 30), status=1),
#  NewConcert(id=None, uid='5b8a278b-9ca8-42e6-a38c-76bfbe0d7f61', artist='Tate McRae', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 11, 1, 19, 0), status=1),
#  NewConcert(id=None, uid='4034f315-55a2-46f4-9e0f-3a16847e97da', artist='Brandy and Monica', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 12, 7, 19, 0), status=1),
#  NewConcert(id=None, uid='0f3e0dd7-7c94-4049-bf74-3d2625b71f0b', artist='Ana Gabriel', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 27, 20, 0), status=1),
#  NewConcert(id=None, uid='faec6218-896b-4cb9-b814-30b0e940eee8', artist='Lil Wayne', tour_name='', venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 18, 20, 0), status=1),
#  NewConcert(id=None, uid='c11c6f4b-6125-4523-b126-1f750d1a9612', artist='Laufey', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 20, 19, 30), status=1),
#  NewConcert(id=None, uid='15c1cd4a-dcd5-4fcf-8167-b1c37694e30b', artist='Houston Livestock Show and Rodeo - Cody Johnson (Concert Only, No Houston Rodeo Performance)', tour_name='', venue='NRG Stadium', location='Houston, TX, USA', datetime=datetime.datetime(2025, 3, 22, 23, 59), status=1),
#  NewConcert(id=None, uid='219dacf8-e8ab-4cf1-a459-84b133d30993', artist='Jonas Brothers', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 19, 19, 30), status=1),
#  NewConcert(id=None, uid='27a9ccce-4010-475a-822b-5f86a44e1560', artist='Bring Me The Horizon', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 26, 19, 0), status=1),
#  NewConcert(id=None, uid='d579e6f6-e98f-4bcc-a67e-66975d54b121', artist='Katseye', tour_name='', venue='Smart Financial Centre', location='Houston, TX, USA', datetime=datetime.datetime(2025, 11, 29, 20, 0), status=1),
#  NewConcert(id=None, uid='d29dc68a-2780-4738-8479-dbba30e77bd1', artist='The Lumineers', tour_name='', venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 10, 19, 30), status=1),
#  NewConcert(id=None, uid='215ce852-5843-4eec-8fc3-8e2a01f393b7', artist='Junior H', tour_name='', venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 4, 20, 0), status=1),
#  NewConcert(id=None, uid='f3bcfaea-a638-4d31-a7f8-d58f52ca4916', artist='SuicideBoys', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 10, 10, 18, 30), status=1),
#  NewConcert(id=None, uid='8703d00c-dc7c-4df6-95c6-012ebfbe282b', artist='Nine Inch Nails', tour_name='', venue='Toyota Center - TX', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 30), status=1),
#  NewConcert(id=None, uid='9325f6e3-5923-4c7a-ad0f-c8da93e524db', artist='Insane Clown Posse', tour_name='', venue='The Lawn at White Oak Music Hall', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 14, 16, 30), status=1),
#  NewConcert(id=None, uid='552cd8a3-342f-446d-a340-0a61c30090db', artist='Southern Soul Explosion', tour_name='', venue='Smart Financial Centre', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='19aa6206-1eb1-4531-89e1-23d3c4d3b233', artist='AJ McQueen', tour_name='', venue='The Bronze Peacock at House of Blues Houston', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 13, 19, 0), status=1),
#  NewConcert(id=None, uid='949d7af2-4b43-4dae-9942-4ddd7f4b39d4', artist='Samia', tour_name='', venue='The Heights Theater', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='ccee2775-8fd5-4d56-85ee-e12b356d6f30', artist='Brian Simpson', tour_name='', venue='Main Street Crossing', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 13, 16, 0), status=1),
#  NewConcert(id=None, uid='908ea422-b61e-4139-a4bd-e27fae46ad77', artist='Buena Vista Social Orchestra', tour_name='', venue='Bayou Music Center', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='a4c07b93-fa39-4566-8ec1-f7133b2e8710', artist='TOPS', tour_name='', venue='The Heights Theater', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='cad0cd6d-0c67-4dc8-bc70-16b6d2888a8d', artist='G Flip', tour_name='', venue='White Oak Music Hall - Downstairs', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 0), status=1),
#  NewConcert(id=None, uid='51448841-9d82-4cb2-8aa5-61ca478b2f3c', artist='SideQuest (18+ Event)', tour_name='', venue='Stereo Live Houston', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 12, 22, 0), status=1),
#  NewConcert(id=None, uid='464b644f-b540-41c4-a175-d2fb2ad7e992', artist='Joe Kay', tour_name='', venue='White Oak Music Hall - Downstairs', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='a523fe5b-0e2b-4c2e-bc2e-d471031a603f', artist='Powerslave - The Iron Maiden Experience', tour_name='', venue='Scout Bar - Houston', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 12, 21, 0), status=1),
#  NewConcert(id=None, uid='cdb8fd36-cc58-484a-86e9-947e1583daea', artist='Hardwired To Kill Em All - Metallica Tribute (18+ Event)', tour_name='', venue='Scout Bar - Houston', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 13, 21, 0), status=1),
#  NewConcert(id=None, uid='ced4bb98-4b80-4f07-9b3a-72576f7424dd', artist='East of Eado', tour_name='', venue='White Oak Music Hall - Upstairs', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 13, 19, 0), status=1),
#  NewConcert(id=None, uid='b7a40297-d16b-4649-baa4-8d4edaf73aef', artist='Mehro', tour_name='', venue='White Oak Music Hall - Upstairs', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 14, 20, 0), status=1),
#  NewConcert(id=None, uid='046ead70-a38f-4cc8-8b02-2daa30936d07', artist='Wreckno (18+ Event)', tour_name='', venue='9PM Music Venue', location='Houston, TX, USA', datetime=datetime.datetime(2025, 9, 12, 21, 0), status=1),
#  NewConcert(id=None, uid='c8b97e59-4ee8-4e20-98bd-c26fa0699638', artist='Paul McCartney', tour_name='', venue='Alamodome', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 25, 20, 0), status=1),
#  NewConcert(id=None, uid='fd373525-41f4-4a61-b499-5572c921341b', artist='Brandon Lake', tour_name='', venue='Frost Bank Center', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 4, 9, 19, 0), status=1),
#  NewConcert(id=None, uid='365b8162-30bd-443e-9ef8-85c1847757ab', artist='Role Model', tour_name='', venue='Aztec Theatre', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 2, 20, 0), status=1),
#  NewConcert(id=None, uid='8398ab78-501f-44fe-961c-dd38e2bc2688', artist='Air1 Worship Now - Phil Wickham, Charity Gayle, and Josh Baldwin', tour_name='', venue='Freeman Coliseum', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 17, 19, 0), status=1),
#  NewConcert(id=None, uid='a16b6023-b2ed-4341-a588-4e6ffa91f48f', artist='Tucker Wetmore (Rescheduled from 5/2)', tour_name='', venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 26, 20, 30), status=1),
#  NewConcert(id=None, uid='4a8876e0-9434-435c-a212-cb906fbd52ab', artist='Christian Nodal', tour_name='', venue='Frost Bank Center', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 11, 23, 20, 0), status=1),
#  NewConcert(id=None, uid='4132c0df-59e6-420a-ae5d-9ccc7a029a40', artist='Ramon Ayala', tour_name='', venue='Freeman Coliseum', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 4, 20, 30), status=1),
#  NewConcert(id=None, uid='21bd3b6d-3f2d-4b22-91f1-53e3a7956dea', artist='Randy Travis', tour_name='', venue='Majestic Theatre San Antonio', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 3, 19, 0), status=1),
#  NewConcert(id=None, uid='73bfcffd-128d-445e-8cc9-871c45cef969', artist='Midland', tour_name='', venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 11, 8, 19, 0), status=1),
#  NewConcert(id=None, uid='703ed2f3-b221-4a3a-9968-0c2b24807f59', artist='The Cult', tour_name='', venue='Majestic Theatre San Antonio', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 21, 19, 30), status=1),
#  NewConcert(id=None, uid='ab7c0f0a-7e19-4332-8259-3b884fa1c570', artist='Rilo Kiley (21+ Event)', tour_name='', venue='Aztec Theatre', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 8, 20, 0), status=1),
#  NewConcert(id=None, uid='f03e193d-2139-43f9-a51b-4811be0b476a', artist='Durand Jones', tour_name='', venue='Aztec Theatre', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 15, 20, 0), status=1),
#  NewConcert(id=None, uid='e485a850-72cc-497b-b5b5-3a854a9bf40a', artist='Michael Schenker', tour_name='', venue='Tobin Center for the Performing Arts', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 10, 19, 30), status=1),
#  NewConcert(id=None, uid='d4b9d0eb-4f30-4b5b-8a65-50b53a2ea362', artist='William Beckmann (18+ Event)', tour_name='', venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 20, 19, 30), status=1),
#  NewConcert(id=None, uid='86f8e996-3c74-47ef-991a-6c0e579354bf', artist='Melissa Etheridge and Indigo Girls', tour_name='', venue='The Espee Pavilion at St. Paul Square', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 9, 19, 0), status=1),
#  NewConcert(id=None, uid='e20c04f4-82b7-43fb-b338-bf9fa289a282', artist='2hollis', tour_name='', venue='Aztec Theatre', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 24, 20, 0), status=1),
#  NewConcert(id=None, uid='7f515ba5-6068-4349-bcb4-294c39597822', artist='Chris Brown', tour_name='', venue='Alamodome', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 27, 19, 0), status=1),
#  NewConcert(id=None, uid='e74db52a-2fd3-418a-bf0e-c1fa58872555', artist='Paul McCartney', tour_name='', venue='Alamodome', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 25, 20, 0), status=1),
#  NewConcert(id=None, uid='4c15b58e-1492-4a4e-bea5-948e3e5fec68', artist='Ella Langley', tour_name='', venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 17, 20, 30), status=1),
#  NewConcert(id=None, uid='afa02203-ef47-4002-a239-a2c6fcb4ca18', artist='NBA YoungBoy', tour_name='', venue='Frost Bank Center', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 29, 19, 0), status=1),
#  NewConcert(id=None, uid='1ab24c88-90f0-41b3-8197-9cea2c86776c', artist='Morrissey (Rescheduled from 5/8/2025)', tour_name='', venue='Boeing Center at Tech Port', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 1, 10, 19, 0), status=1),
#  NewConcert(id=None, uid='a451ace1-7058-4817-b5e0-ac695720c31d', artist='Jonas Brothers', tour_name='', venue='Frost Bank Center', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 18, 19, 30), status=1),
#  NewConcert(id=None, uid='26107e3f-d33e-4cb8-9492-710ee4609f69', artist='Brandon Lake', tour_name='', venue='Frost Bank Center', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 4, 9, 19, 0), status=1),
#  NewConcert(id=None, uid='46f79083-06e4-452e-a082-08a45ee71aaa', artist='Role Model', tour_name='', venue='Aztec Theatre', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 2, 20, 0), status=1),
#  NewConcert(id=None, uid='1a21f9fd-1284-41e4-80c1-13adb08a7865', artist='Cage The Elephant', tour_name='', venue='Boeing Center at Tech Port', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 4, 19, 0), status=1),
#  NewConcert(id=None, uid='faae6fec-7995-4577-8e83-1c7fac2213c7', artist='Air1 Worship Now - Phil Wickham, Charity Gayle, and Josh Baldwin', tour_name='', venue='Freeman Coliseum', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 17, 19, 0), status=1),
#  NewConcert(id=None, uid='db2c2bfa-4e80-4f3f-9eb6-8da4bfd31a3e', artist='Twilight in Concert', tour_name='', venue='Majestic Theatre San Antonio', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 12, 19, 30), status=1),
#  NewConcert(id=None, uid='bb2468bd-29b3-416e-aa39-b8532011daa2', artist='Tucker Wetmore (Rescheduled from 5/2)', tour_name='', venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 26, 20, 30), status=1),
#  NewConcert(id=None, uid='04fe41a1-03d3-40ab-bb0c-ab44e19b2366', artist='Christian Nodal', tour_name='', venue='Frost Bank Center', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 11, 23, 20, 0), status=1),
#  NewConcert(id=None, uid='4a8d910e-d969-4445-8ccc-93774a30ea19', artist='San Antonio Stock Show and Rodeo - Miranda Lambert', tour_name='', venue='Frost Bank Center', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 2, 18, 19, 0), status=1),
#  NewConcert(id=None, uid='42091966-c43a-4da9-bf09-9a2a56cae260', artist='Ramon Ayala', tour_name='', venue='Freeman Coliseum', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 4, 20, 30), status=1),
#  NewConcert(id=None, uid='d31ddc6e-5516-4e2c-a9eb-53fe84b2cfde', artist='Randy Travis', tour_name='', venue='Majestic Theatre San Antonio', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 10, 3, 19, 0), status=1),
#  NewConcert(id=None, uid='32dbc28c-a5ef-4663-a785-edc070060d1c', artist='Jamey Johnson (18+ Event)', tour_name='', venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 30), status=1),
#  NewConcert(id=None, uid='e6e146dd-d69a-4798-9a91-b173ecf0d032', artist='Insane Clown Posse', tour_name='', venue='The Espee Pavilion at St. Paul Square', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 12, 18, 0), status=1),
#  NewConcert(id=None, uid='f0c2012d-7b70-4284-b89f-fa8acb8a7f28', artist='Sidewalks and Skeletons (18+ Event)', tour_name='', venue='Sams Burger Joint', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 30), status=1),
#  NewConcert(id=None, uid='d5e16d95-7a47-4354-8114-7d012733fb2b', artist='Giovannie and The Hired Guns', tour_name='', venue='Gruene Hall', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 12, 21, 30), status=1),
#  NewConcert(id=None, uid='5c0d841e-ec90-4119-812d-c0edf483d765', artist='Candlelight - A Tribute to Adele', tour_name='', venue='The Josephine Theatre', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 30), status=1),
#  NewConcert(id=None, uid='e44e52dc-da39-4e28-8c7d-51e8c7a838c9', artist='Mitchell Ferguson (18+ Event)', tour_name='', venue='Cheatham Street Warehouse', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='327c082c-d914-4a58-a614-b391cf5c43b5', artist='Donny Edwards', tour_name='', venue='Brauntex Performing Arts Theatre', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 13, 19, 30), status=1),
#  NewConcert(id=None, uid='b32c30d5-35cb-451d-8089-60cf9e6b2cfb', artist='William Clark Green', tour_name='', venue='Stable Hall', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='9d94a11d-0143-45f4-926e-7c6b2e36d5fc', artist='The Damn Torpedoes - A Tribute to Tom Petty and The Heartbreak', tour_name='', venue='Sams Burger Joint', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 30), status=1),
#  NewConcert(id=None, uid='9ffc0e6c-3aa1-4d4e-af5a-ded22a69d12b', artist='THEBROSFRESH', tour_name='', venue='Paper Tiger', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 12, 21, 0), status=1),
#  NewConcert(id=None, uid='b1df6b80-5354-4c93-a554-09074fcebf9c', artist='Caskey', tour_name='', venue='Paper Tiger', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 13, 19, 0), status=1),
#  NewConcert(id=None, uid='2482b354-9e50-4f9b-a997-00eee69366ec', artist='Dopamine', tour_name='', venue='Paper Tiger', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 13, 22, 0), status=1),
#  NewConcert(id=None, uid='8dfaf675-43ed-44d1-932d-d874d0f3922e', artist='Dark Angel', tour_name='', venue='Vibes Event Center', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 12, 18, 30), status=1),
#  NewConcert(id=None, uid='52b86ce2-f6c1-4a6a-bcb4-b24c1b537e73', artist='Roger Clyne', tour_name='', venue='Bucks Backyard', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='a650d8aa-1d14-4f16-a437-d8acf8704146', artist='LC Rocks', tour_name='', venue='Bucks Backyard', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 13, 21, 0), status=1),
#  NewConcert(id=None, uid='c733c554-1ade-48e7-af9b-8024d203ef4a', artist='Bottomland (18+ Event)', tour_name='', venue='Cheatham Street Warehouse', location='San Antonio, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='c8218a12-3f24-49cc-bd71-0801c516cba0', artist='Luke Bryan (Rescheduled from 6/20)', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 0), status=1),
#  NewConcert(id=None, uid='16a65597-5140-412d-91a3-6170535cc044', artist='Dua Lipa', tour_name='', venue='American Airlines Center - TX', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 30, 19, 30), status=1),
#  NewConcert(id=None, uid='cff1490c-0d86-456d-b8f2-02ae6049b904', artist='SuicideBoys', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 13, 18, 30), status=1),
#  NewConcert(id=None, uid='38eaa19f-ffcc-44ba-a3fb-d3ce968519e0', artist='Ella Langley (18+ Event)', tour_name='', venue='Billy Bobs', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 18, 22, 0), status=1),
#  NewConcert(id=None, uid='ddbddd90-4b02-495e-bc15-6d76754069fb', artist='Bring Me The Horizon', tour_name='', venue='American Airlines Center - TX', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 27, 18, 0), status=1),
#  NewConcert(id=None, uid='2edd7af7-eb48-4319-8f7b-fb50a9ec9295', artist='The Red Clay Strays', tour_name='', venue='Pavilion at Toyota Music Factory', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 25, 20, 0), status=1),
#  NewConcert(id=None, uid='f2f41648-5050-4768-a5df-caee0bbf0855', artist='Lil Wayne', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 17, 20, 0), status=1),
#  NewConcert(id=None, uid='3c9680f6-fbbf-4d3a-af0e-4766166d950f', artist='Keith Urban', tour_name='', venue='Dickies Arena', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 9, 19, 0), status=1),
#  NewConcert(id=None, uid='bdefbb5f-2298-4cea-b2c5-4671fceb390a', artist='James Taylor', tour_name='', venue='Dickies Arena', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 17, 19, 30), status=1),
#  NewConcert(id=None, uid='ae53a3ec-6dda-41cf-ae85-7fd8a6c3d7e0', artist='Sombr (Moved from Cambridge Room at House of Blues Dallas, South Side Music Hall)', tour_name='', venue='Credit Union of Texas Event Center', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 17, 20, 0), status=1),
#  NewConcert(id=None, uid='9471b22e-5275-4070-b989-1065be5657da', artist='Dom Dolla (18+ Event)', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 11, 1, 18, 30), status=1),
#  NewConcert(id=None, uid='5a49e146-d313-45c4-8d11-8af7af1161db', artist='Maroon 5', tour_name='', venue='American Airlines Center - TX', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 11, 7, 20, 0), status=1),
#  NewConcert(id=None, uid='e382c231-86a0-475e-b5d6-a4674d18cc10', artist='T-Pain', tour_name='', venue='Pavilion at Toyota Music Factory', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 22, 19, 45), status=1),
#  NewConcert(id=None, uid='0b53a1a5-cb62-4684-b0c5-69c02177c189', artist='Junior H', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 26, 20, 0), status=1),
#  NewConcert(id=None, uid='d238eea6-6bb6-4b17-9ab5-7978ab55bad0', artist='Alejandro Fernandez (Rescheduled from 9/6)', tour_name='', venue='Dickies Arena', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 18, 20, 0), status=1),
#  NewConcert(id=None, uid='32121113-3a90-40ce-82a6-679f630197a6', artist='Gavin Adcock', tour_name='', venue='Pavilion at Toyota Music Factory', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 30), status=1),
#  NewConcert(id=None, uid='61705f64-a719-42a3-a1a4-e866b3da3fdc', artist='Benson Boone', tour_name='', venue='Dickies Arena', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1),
#  NewConcert(id=None, uid='f00d1350-ba4c-459a-868e-fff8d0317183', artist='Lainey Wilson', tour_name='', venue='Dickies Arena', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 19, 19, 0), status=1),
#  NewConcert(id=None, uid='1c82cd8b-85d9-41c4-b38b-7cc0f4d4b6a7', artist='Nine Inch Nails', tour_name='', venue='Dickies Arena', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 13, 19, 30), status=1),
#  NewConcert(id=None, uid='2c3be926-210e-4594-b352-bfb78399e940', artist='Tate McRae', tour_name='', venue='American Airlines Center - TX', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 18, 19, 0), status=1),
#  NewConcert(id=None, uid='16540800-031a-42b7-9205-3e5dbe6dd849', artist='Megan Moroney', tour_name='', venue='Texas Trust CU Theatre at Grand Prairie', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 11, 20, 0), status=1),
#  NewConcert(id=None, uid='32674b81-fcd3-4a39-b3b1-3d6dd5654ddc', artist='Luke Bryan (Rescheduled from 6/20)', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 0), status=1),
#  NewConcert(id=None, uid='5650d0de-c23f-4f02-9ba7-1e096b1f15de', artist='Dua Lipa', tour_name='', venue='American Airlines Center - TX', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 30, 19, 30), status=1),
#  NewConcert(id=None, uid='5075d370-f719-476e-9dd7-20b4e1ac45a1', artist='SuicideBoys', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 13, 18, 30), status=1),
#  NewConcert(id=None, uid='5763238b-1979-4c98-9143-9bade7b43c66', artist='Twenty One Pilots', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 20, 20, 0), status=1),
#  NewConcert(id=None, uid='b34140d1-fa0d-4841-86a4-1e2335dfaccd', artist='Ella Langley (18+ Event)', tour_name='', venue='Billy Bobs', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 18, 22, 0), status=1),
#  NewConcert(id=None, uid='c955181e-f276-49bc-ac39-c6f1094a4075', artist='The Lumineers', tour_name='', venue='Dickies Arena', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 11, 19, 30), status=1),
#  NewConcert(id=None, uid='ba2d2c9e-fc36-4dcf-8209-1cbb418a6e53', artist='Bring Me The Horizon', tour_name='', venue='American Airlines Center - TX', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 27, 18, 0), status=1),
#  NewConcert(id=None, uid='c8d0cc52-38a5-43d2-b27f-74dc23638eb3', artist='The Red Clay Strays', tour_name='', venue='Pavilion at Toyota Music Factory', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 25, 20, 0), status=1),
#  NewConcert(id=None, uid='612989a2-ce63-4d57-8379-983931c848c0', artist='Junior H', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 10, 25, 20, 0), status=1),
#  NewConcert(id=None, uid='6e3fd9ff-33e1-4ea3-bb48-539059d5b9ff', artist='Brandy and Monica', tour_name='', venue='Dickies Arena', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 12, 6, 20, 0), status=1),
#  NewConcert(id=None, uid='e005d8e2-e6e6-422d-985f-7669e0ce18b6', artist='Laufey', tour_name='', venue='Dickies Arena', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 18, 19, 30), status=1),
#  NewConcert(id=None, uid='ebf97b92-1f20-46bd-a674-04d2d4ab996a', artist='Nine Inch Nails', tour_name='', venue='Dickies Arena', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 13, 19, 30), status=1),
#  NewConcert(id=None, uid='12070763-bc52-458a-b562-f1ceb0f02864', artist='Luke Bryan (Rescheduled from 6/20)', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 0), status=1),
#  NewConcert(id=None, uid='8eebb745-aae5-4fae-8ebf-bacb015a7de7', artist='SuicideBoys', tour_name='', venue='Dos Equis Pavilion', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 13, 18, 30), status=1),
#  NewConcert(id=None, uid='b6af1b3b-9cf5-4bd4-9e55-42c68e1cef66', artist='Gavin Adcock', tour_name='', venue='Pavilion at Toyota Music Factory', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 30), status=1),
#  NewConcert(id=None, uid='556604c7-e819-499c-8829-ee6d4cf86ddc', artist='Manuel Turizo', tour_name='', venue='Texas Trust CU Theatre at Grand Prairie', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='c76eb0b3-6284-43ab-890e-55c279e102f1', artist='King George', tour_name='', venue='Will Rogers Auditorium', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='6c260a4a-0fd1-4725-b592-7f0f070cf707', artist='Trace Adkins and John Michael Montgomery', tour_name='', venue='Texas Trust CU Theatre at Grand Prairie', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 14, 18, 30), status=1),
#  NewConcert(id=None, uid='a93cefac-270a-4162-9442-3281c284142b', artist='Atif Aslam', tour_name='', venue='Curtis Culwell Center', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 13, 19, 0), status=1),
#  NewConcert(id=None, uid='22eff85d-857b-4060-9ab4-7cbbc8285f75', artist='Lea Salonga', tour_name='', venue='Winspear Opera House', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 14, 19, 30), status=1),
#  NewConcert(id=None, uid='c7dd4c52-1d0e-4d86-9c4f-9d18c54e72da', artist='Gorgon City (18+ Event)', tour_name='', venue='SILO Dallas', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 12, 21, 0), status=1),
#  NewConcert(id=None, uid='0f16b7ac-c9c1-4e85-885a-43442e5fec6a', artist='The Swell Season', tour_name='', venue='Majestic Theatre Dallas', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 12, 19, 0), status=1),
#  NewConcert(id=None, uid='a81ee767-f2fa-4d8d-ad6d-07a7f6598788', artist='G Flip', tour_name='', venue='The Bomb Factory', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='f688f73f-4292-48cc-87de-5b6d469d0939', artist='Mexico in Our Blood', tour_name='', venue='Cowtown Coliseum', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 14, 14, 0), status=1),
#  NewConcert(id=None, uid='f99af3ee-539a-42c3-a707-467a63d67ca8', artist='Los Parras', tour_name='', venue='Far West', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='6b84f912-ddc7-4336-87f2-7f6071686f0c', artist='Darius', tour_name='', venue='The Studio at The Bomb Factory', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 14, 20, 0), status=1),
#  NewConcert(id=None, uid='c52a4b42-fdc0-4128-8b23-348e5c6d142e', artist='CLUB 1BD (18+ Event)', tour_name='', venue='The Echo Lounge and Music Hall', location='Dallas, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='3d33ff0d-22e0-4941-bd7b-64af0baa9134', artist='Alejandro Fernandez (Rescheduled from 9/7)', tour_name='', venue='Don Haskins Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 19, 20, 30), status=1),
#  NewConcert(id=None, uid='b16945da-b354-455d-9d9e-faf0afc0fc31', artist='Christian Nodal', tour_name='', venue='Don Haskins Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 11, 16, 20, 0), status=1),
#  NewConcert(id=None, uid='53401e4c-be81-4ae2-916a-14885f8cbdf5', artist='Banda Ms', tour_name='', venue='Don Haskins Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 25, 20, 0), status=1),
#  NewConcert(id=None, uid='dcba1614-753d-4a15-b1f9-56f6512b35ea', artist='Eden Munoz', tour_name='', venue='Abraham Chavez Theatre', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 11, 20, 0), status=1),
#  NewConcert(id=None, uid='039a1319-34f9-4b2c-ac5d-43450972dbfd', artist='Chris Lake', tour_name='', venue='El Paso County Coliseum', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 12, 12, 19, 0), status=1),
#  NewConcert(id=None, uid='f2c67e80-3e7c-44b4-9896-8da40cb01b47', artist='KLAQ Rocks the Park with Scott Stapp', tour_name='', venue='Southwest University Park', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 4, 23, 59), status=1),
#  NewConcert(id=None, uid='4fbf6401-4ecc-4455-a41f-413bb29248bc', artist='ROZ', tour_name='', venue='Lowbrow Palace', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 10, 20, 0), status=1),
#  NewConcert(id=None, uid='b3439ed8-28cd-4e47-9299-f9ab6c21a59b', artist='Jesse and Joy', tour_name='', venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 1, 30, 20, 0), status=1),
#  NewConcert(id=None, uid='fbafe3bd-4904-4f68-81c3-887d798ecc7c', artist='Midland', tour_name='', venue='Cowtown Outdoor Venue', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 2, 20, 0), status=1),
#  NewConcert(id=None, uid='c2b2c3ba-e713-4070-9fc6-9998d79faf65', artist='Xavi', tour_name='', venue='El Paso County Coliseum', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 11, 20, 20, 0), status=1),
#  NewConcert(id=None, uid='cdd559b0-f581-482b-9632-87f0942ab155', artist='Way Out West Music Festival', tour_name='', venue='El Paso Convention Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 9, 27, 17, 0), status=1),
#  NewConcert(id=None, uid='93215440-cec9-48e4-b1aa-b0a758edbefd', artist='Pancho Barraza', tour_name='', venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 24, 20, 0), status=1),
#  NewConcert(id=None, uid='381dbf23-6e29-434d-93f3-01b81fb6aef6', artist='Los Horoscopos De Durango', tour_name='', venue='Abraham Chavez Theatre', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 17, 20, 0), status=1),
#  NewConcert(id=None, uid='eec714c7-fb76-42e7-8e3d-928b7f361829', artist='Intocable', tour_name='', venue='El Paso County Coliseum', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 11, 8, 20, 0), status=1),
#  NewConcert(id=None, uid='ca02aee4-b7da-4dad-8a93-f14ad074ad9f', artist='Clave Especial', tour_name='', venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 9, 28, 20, 0), status=1),
#  NewConcert(id=None, uid='cdb7a8f7-f599-4f90-b9cd-ac4491e2d5f6', artist='Bandalos Chinos', tour_name='', venue='Lowbrow Palace', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 4, 19, 0), status=1),
#  NewConcert(id=None, uid='43cbc739-52c9-444c-be8d-3c8b8c6a19c2', artist='The Strokes', tour_name='', venue='Abraham Chavez Theatre', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 1, 20, 0), status=1),
#  NewConcert(id=None, uid='51816ab1-b6ad-4774-a1d6-864bd353ae02', artist='Alejandro Fernandez (Rescheduled from 9/7)', tour_name='', venue='Don Haskins Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 19, 20, 30), status=1),
#  NewConcert(id=None, uid='b423b708-96a5-43c6-a9a0-1cbf4651f574', artist='Miguel Bose', tour_name='', venue='El Paso County Coliseum', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 17, 20, 30), status=1),
#  NewConcert(id=None, uid='501cb2c5-4c57-4a36-ae2c-3fed1277fcdd', artist='Christian Nodal', tour_name='', venue='Don Haskins Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 11, 16, 20, 0), status=1),
#  NewConcert(id=None, uid='993023ce-b527-4cec-8b53-ea05a9d80580', artist='Banda Ms', tour_name='', venue='Don Haskins Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 25, 20, 0), status=1),
#  NewConcert(id=None, uid='b1f433ad-df7f-4a4a-a729-3e852bf9f7cb', artist='Eden Munoz', tour_name='', venue='Abraham Chavez Theatre', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 11, 20, 0), status=1),
#  NewConcert(id=None, uid='15ed5b88-9350-4951-9ae6-94cb4bd75f35', artist='Chelo - El Adios de Una Grande (Rescheduled from 6/28)', tour_name='', venue='El Paso County Coliseum', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 11, 22, 19, 30), status=1),
#  NewConcert(id=None, uid='65802ac2-fcaf-481a-afc6-09e0e29aa83d', artist='Chris Lake', tour_name='', venue='El Paso County Coliseum', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 12, 12, 19, 0), status=1),
#  NewConcert(id=None, uid='11a88dea-fa6a-4067-9c8a-39b6466cf878', artist='KLAQ Rocks the Park with Scott Stapp', tour_name='', venue='Southwest University Park', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 4, 23, 59), status=1),
#  NewConcert(id=None, uid='0a1f12e9-bd70-4fb8-ad87-e9bad68dfde9', artist='ROZ', tour_name='', venue='Lowbrow Palace', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 10, 20, 0), status=1),
#  NewConcert(id=None, uid='21c96ba1-2819-41a2-8f97-64e0d81dbb7f', artist='Amanda Miguel', tour_name='', venue='El Paso County Coliseum', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 11, 21, 20, 30), status=1),
#  NewConcert(id=None, uid='62050c75-aff8-4a1c-968a-224ac823858f', artist='Marisela', tour_name='', venue='El Paso County Coliseum', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 18, 20, 0), status=1),
#  NewConcert(id=None, uid='32e68017-2731-4ce6-92d6-ab1a8a823922', artist='Cuco', tour_name='', venue='Lowbrow Palace', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 9, 21, 19, 0), status=1),
#  NewConcert(id=None, uid='04487955-c003-41ba-adfe-4630c924dd38', artist='Jesse and Joy', tour_name='', venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 1, 30, 20, 0), status=1),
#  NewConcert(id=None, uid='64be0f67-38c6-4a83-ad60-27e0aec688ce', artist='Midland', tour_name='', venue='Cowtown Outdoor Venue', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 10, 2, 20, 0), status=1),
#  NewConcert(id=None, uid='e4bdff11-56dc-422f-9ef9-d7467cd78815', artist='Brincos Dieras and Kevyn Contreras', tour_name='', venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1),
#  NewConcert(id=None, uid='ed382c2e-4704-4ba3-a668-743241d8ebfc', artist='Yuri', tour_name='', venue='El Paso County Coliseum', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 9, 13, 19, 0), status=1),
#  NewConcert(id=None, uid='07a83348-98f1-4728-8544-9fa44437894d', artist='TOPS', tour_name='', venue='Lowbrow Palace', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 9, 14, 20, 0), status=1),
#  NewConcert(id=None, uid='64b80fed-d071-438a-a929-a828f013ae07', artist='The Mccharmlys', tour_name='', venue='Lowbrow Palace', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 9, 12, 20, 0), status=1),
#  NewConcert(id=None, uid='7845be54-c360-46ad-a4c8-42338211b7bf', artist='Jon Wolfe', tour_name='', venue='Lowbrow Palace', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 0), status=1),
#  NewConcert(id=None, uid='ace71c22-c832-4b20-a67c-bc38c6eb3e72', artist='Zuezeu', tour_name='', venue='808', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 9, 13, 21, 0), status=1),
#  NewConcert(id=None, uid='595dbfb7-a389-42fe-a9c1-9cc65e48026a', artist='Candlelight - Coldplay and Imagine Dragons', tour_name='', venue='El Paso Zoo', location='El Paso, TX, USA', datetime=datetime.datetime(2025, 9, 13, 20, 30), status=1)]

# %%
import os
from dotenv import load_dotenv
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# get password and uri for database connection
load_dotenv()
db_password = os.getenv('MONGO_PASSWORD')
uri = os.getenv('DATABASE_URI').replace('db_password', db_password)

# create client and connect to server
client = MongoClient(uri, server_api=ServerApi('1'))

# ping for confirmation and update databases
db = client['bigcat']
# for concert in concert_data:
#     db['concert'].insert_one(concert.__dict__)

# %%
# pipeline = [
#     {
#         '$group': {
#             '_id': {'artist': '$artist', 'tour_name': '$tour_name', 'venue': '$venue', 'location': '$location', 'datetime': '$datetime', 'status': '$status'},
#             'duplicate_ids': {'$push': '$uid'},
#             'count': {'$sum': 1}
#         }
#     },
#     {
#         '$match': {
#             'count': {'$gt': 1}
#         }
#     }
# ]

# duplicates = list(db['concert'].aggregate(pipeline))
# print(f'{len(duplicates)} duplicates found.')

# counter = 0

# for doc in duplicates:
#         ids_to_remove = doc['duplicate_ids'][1:]  # Keep the first, remove the rest
#         if ids_to_remove:
#             db['concert'].delete_many({'uid': {'$in': ids_to_remove}})
#         counter += 1

# print(f"{counter} duplicate documents removed.")
# Out:
# ['fac3bfdd-3d27-43ec-81fe-13654edfe7c9']
# ['80f21e86-79db-415d-8cd1-d8391ff9b9be']
# ['cace0725-46e4-402b-b578-2dca477cac43']
# ['cae57419-86ec-4e6c-ba24-3c725be42e88']
# ['169058a6-cbb0-4206-9db2-4afb8f8eb39e']
# ['c8fad048-2436-4033-957f-d981082709df', '59de29a8-b1a1-4b4f-a2e3-8d3d9b312eb3']
# ['e4fc8d33-7e29-4cf7-9322-d2cd539c18ab']
# ['4e0ec9f4-9d99-4682-9645-c63db2bbc210']
# ['ae9d9ae5-4f4c-4263-a5e8-d15db431d204']
# ['05b9be65-0e25-4a9a-a26c-baeac47092e5']
# ['9aca81db-4ef1-4201-8948-eb01f375a617']
# ['8600d4bf-92a2-47a7-8c24-dfe2d6870dda']
# ['ef65448e-fc3f-4add-b9fc-9cf339afb4a8']
# ['46885503-1f71-4766-a7fe-225ede9fa3a0']
# ['a18796c0-ebcf-45c5-bec7-ec0a8edc6233']
# ['d4781fc0-2585-4f44-8402-43a527daa8af', '218bdf0e-f3dd-488b-9e63-a2918784f7e2']
# ['1427eeae-983c-490c-b152-c840eaabc824']
# ['55c5ee9a-8a6f-423b-bdc0-7f4d86741926']
# ['0c7ab01c-3181-4f2f-b226-a0b5e8c15427']
# ['37785226-ea13-48e6-8687-11cc07866fdb', '33a66b45-7e13-46ca-820b-e107798ac003']
# ['58b416b2-9213-4ec0-9730-7ee925423e48']
# ['b406d9ec-7afd-42a0-a91b-7d08038a93fb']
# ['1d31f2cf-3721-4970-9575-04f3ec02d743']
# ['c04f4e2e-3123-4a22-b31e-81f4103b90ab']
# ['866fceff-a0ca-48f9-9f79-2e5345dbf60d']
# ['26f52a2f-d6e7-4a3c-b51f-a2481401105e']
# ['e213711b-4249-44e6-94a5-6d5ceb450911']
# ['8c9a7886-ea9b-450d-aeb5-72e58660633a']
# ['66b4df94-6a12-4ae6-b4f5-9dc095ec64fa']
# ['390e5338-5627-483d-ad6a-32dd8f93083e']
# ['a322195c-0c83-49c5-8b23-8a4872cb9755']
# ['aa7612d9-dd79-42ed-bd8f-0999975f5a4d']
# ['9a523452-95ab-4da9-bf30-c96d7455f17a']
# ['b289d8bf-7c09-4103-b0bb-d011db6e2af4']
# ['e484cc3a-afe7-480b-8509-8ae297aa0f7e']
# ['978e05bc-fd88-4060-b3a3-3229c6ba1f15']
# ['5673281a-e8ed-4aaa-ba3d-4ee87eac2c23']
# ['7cbfcec9-50aa-4125-97de-eacd6d64c47c']
# ['e8c2b5f9-95b4-4b93-9f29-3afa3ef13140']
# ['3c43810d-3eb5-4797-bd5f-087ffeb680ff']
# ['54ecaced-d78f-4205-a197-3a8d76a793b9']
# ['7c83711e-2014-41a7-8699-640f22ac7a12']
# ['22cda43e-cdb3-4976-8be1-4b686ebf1b39']
# 0 duplicate documents removed.

# %%
set([concert.venue for concert in concert_data if concert.location == 'Austin, TX, USA'])

# moody@admin.bigcat.com
# antones@admin.bigcat.com
# germania@admin.bigcat.com
# paramount@admin.bigcat.com
# Out:
# {'3TEN Austin City Limits Live',
#  "Antone's - Austin",
#  'Austin City Limits Live at The Moody Theater',
#  'Brauntex Performing Arts Theatre',
#  'Cheatham Street Warehouse',
#  'Empire - Control Room',
#  'Germania Insurance Amphitheater',
#  'Gruene Hall',
#  'Long Center for the Performing Arts - Dell Hall',
#  'Moody Amphitheater',
#  'Moody Center ATX',
#  'Paramount Theatre Austin',
#  'Scoot Inn',
#  'Stubbs BarBQ',
#  'The Concourse Project',
#  'Zilker Park'}
