# %%
from pydantic import BaseModel, ConfigDict, BeforeValidator, Field
from enum import Enum
from datetime import datetime
from typing import Optional, Annotated

PyObjectId = Annotated[str, BeforeValidator(str)]

class ConcertStatus(Enum):
    TENTATIVE = 0
    CONFIRMED = 1
    ON_SALE = 2
    SOLD_OUT = 3
    POSTPONED = 4
    CANCELED = 5
    COMPLETED = 6

class NewConcert(BaseModel):
    id: Optional[PyObjectId] = Field(alias='_id', default=None) # primary key
    uid: str
    artist: str
    tour_name: Optional[str] 
    venue: str
    location: str
    concert_datetime: datetime
    status: Optional[ConcertStatus | int]
    update_datetime: datetime

    model_config = ConfigDict(use_enum_values=True)

# %%
import requests
from bs4 import BeautifulSoup
from uuid import uuid4
from datetime import datetime

def get_concert_data(url:str, location:str) -> list:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    m_boxes = soup.find_all('div', class_='MuiCardContent-root styles_cardContent__nFnOO styles_small__RCnB2 mui-15q2cw4')
    cap = soup.find_all(attrs={'data-testid': 'card-venue-name-0'})
    data = []

    for box, caption in zip(m_boxes, cap):
        date = box.div.find_next_sibling("div").find_all("div")[0].text.replace('•', ' ')
        date = datetime.strptime(date, '%a %b %d %I:%M %p')
        date = date.replace(year=datetime.now().year)
        data.append(NewConcert(
            uid=str(uuid4()),
            artist=box.div.span.text,
            tour_name=None,
            venue=caption.text,
            location=location,
            concert_datetime=date,
            status=ConcertStatus.CONFIRMED,
            update_datetime=datetime.now()
        ))

    return data

# %%
concert_data = []
url_list = [('https://www.vividseats.com/geo/usa/tx/austin/concerts', 'Austin, TX, USA'),
            ('https://www.vividseats.com/geo/usa/tx/houston/concerts', 'Houston, TX, USA'),
            ('https://www.vividseats.com/geo/usa/tx/san-antonio/concerts', 'San Antonio, TX, USA'),
            ('https://www.vividseats.com/geo/usa/tx/dallas/concerts', 'Dallas, TX, USA'),
            ('https://www.vividseats.com/geo/usa/tx/el-paso/concerts', 'El Paso, TX, USA')]

for url, location in url_list:
    concert_data.extend(get_concert_data(url, location))

# %%
concert_data
# Out:
# [NewConcert(id=None, uid='578ac440-a2da-419d-b317-1b29e74d96db', artist='Laufey', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 960569)),
#  NewConcert(id=None, uid='0061b2cd-1601-4418-8b99-3c00db113a53', artist='Tate McRae', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 31, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 960684)),
#  NewConcert(id=None, uid='8674dcd6-0efc-4e03-ae6e-52086998d2db', artist='Mumford and Sons', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 24, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 960742)),
#  NewConcert(id=None, uid='c944e31b-113c-48ea-b965-dee30d60e58a', artist='Dom Dolla (18+ Event)', tour_name=None, venue='Germania Insurance Amphitheater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 31, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 960793)),
#  NewConcert(id=None, uid='381d6782-1a77-4af1-9606-29da18733a66', artist='The Lumineers', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 14, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 960842)),
#  NewConcert(id=None, uid='6f131566-f0b1-4185-8a12-fe43c7b6ec21', artist='Addison Rae', tour_name=None, venue='Austin City Limits Live at The Moody Theater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 22, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 960888)),
#  NewConcert(id=None, uid='7f70c39d-9b84-48d1-b099-a811a0aca30b', artist='Jonas Brothers', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 17, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 960933)),
#  NewConcert(id=None, uid='f2db546a-dde0-4fde-9a69-ece3ac2b0c8b', artist='Junior H', tour_name=None, venue='Germania Insurance Amphitheater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 960977)),
#  NewConcert(id=None, uid='7756e256-e06f-462f-ab2e-2eadf738eabe', artist='Crooner and The Cowboy - Leon Bridges and Charley Crockett', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 23, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961023)),
#  NewConcert(id=None, uid='68c77c1a-6988-4181-981e-c7daa5e0b938', artist='Billy Strings', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 12, 13, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961066)),
#  NewConcert(id=None, uid='188f4c2d-f361-4df4-b1d5-11342a49a0fa', artist='Alabama Shakes', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 25, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961110)),
#  NewConcert(id=None, uid='6aa87e7c-a65f-4b7d-a7d6-42963ffd1010', artist='Turnstile', tour_name=None, venue='Moody Amphitheater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 14, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961153)),
#  NewConcert(id=None, uid='897ab5a7-1af3-40f8-9b0d-3f73c0ab7341', artist='Chris Stussy (18+ Event)', tour_name=None, venue='The Concourse Project', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 21, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961194)),
#  NewConcert(id=None, uid='3e0fb0dd-d2b0-432d-bd98-fb6ac8b5bc96', artist='Alice Cooper and Judas Priest', tour_name=None, venue='Germania Insurance Amphitheater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 25, 18, 45), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961236)),
#  NewConcert(id=None, uid='dda4121d-c31a-4493-a8c3-f7647fb3fa19', artist='Disco Lines (18+ Event)', tour_name=None, venue='The Concourse Project', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 4, 21, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961277)),
#  NewConcert(id=None, uid='d03f5b43-330d-4655-9a8c-f0018678c347', artist='Maroon 5', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 11, 4, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961318)),
#  NewConcert(id=None, uid='b9224042-a487-41fd-bbd6-e744a71156ed', artist='Billie Eilish', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 11, 14, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961360)),
#  NewConcert(id=None, uid='8e2cd41b-87b8-42ac-ae2e-0896195e3a8d', artist='2025 Austin City Limits Festival - Weekend One 3 Day Pass (10/3 - 10/5) (Sabrina Carpenter, Hozier, The Killers, Luke Combs, The Strokes, John Summit, Doechii)', tour_name=None, venue='Zilker Park', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 3, 10, 59), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961403)),
#  NewConcert(id=None, uid='3015fd1c-250a-4964-975c-712afa1a5975', artist='Ariana Grande', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 6, 26, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961445)),
#  NewConcert(id=None, uid='a8e92ca8-bf19-4fe9-aed3-58b7ef6e979f', artist='Tame Impala', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 11, 6, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961493)),
#  NewConcert(id=None, uid='51642526-8c52-4085-9c1f-29ae7bc747ea', artist='Lady Gaga', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 3, 8, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961535)),
#  NewConcert(id=None, uid='259a618b-4b79-4a47-bff4-a2615fee7aa6', artist='Laufey', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961577)),
#  NewConcert(id=None, uid='eaa71a02-32d1-42d1-b297-11f69b27bae8', artist='Tate McRae', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 31, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961618)),
#  NewConcert(id=None, uid='45d1ec8c-2191-429c-bd87-a0463011cf41', artist='Mumford and Sons', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 24, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961660)),
#  NewConcert(id=None, uid='98e9ac02-2991-435b-b746-723cf5cd6e25', artist='Dom Dolla (18+ Event)', tour_name=None, venue='Germania Insurance Amphitheater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 31, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961705)),
#  NewConcert(id=None, uid='41bb1abc-eadb-4e1a-8bf1-66d2bf25f9cc', artist='The Lumineers', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 14, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961747)),
#  NewConcert(id=None, uid='a12f6d92-a0f9-4d7f-8b4c-8e283b5eea31', artist='The Red Clay Strays', tour_name=None, venue='Moody Amphitheater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 28, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961790)),
#  NewConcert(id=None, uid='caa17cce-19ea-4fe6-89d5-793c3a669dab', artist='Sombr (Moved from Empire Control Room)', tour_name=None, venue='Stubbs BarBQ', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 18, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961831)),
#  NewConcert(id=None, uid='ba454971-3476-4696-a3aa-14dc9dc533a5', artist='Addison Rae', tour_name=None, venue='Austin City Limits Live at The Moody Theater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 22, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961872)),
#  NewConcert(id=None, uid='5d446802-eb88-446e-96a6-f0f8228d79b2', artist='Jonas Brothers', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 10, 17, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961913)),
#  NewConcert(id=None, uid='7b876269-370a-4578-a43a-c087436157f2', artist='Junior H', tour_name=None, venue='Germania Insurance Amphitheater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961954)),
#  NewConcert(id=None, uid='d430bb01-0846-40f5-8bee-d7b36c8c0353', artist='Crooner and The Cowboy - Leon Bridges and Charley Crockett', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 23, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 961995)),
#  NewConcert(id=None, uid='c0838d07-56af-4408-b65a-e9df7e952b4a', artist='Laufey', tour_name=None, venue='Moody Center ATX', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962040)),
#  NewConcert(id=None, uid='59a64819-4ebe-4d2d-a2d4-6fdd90104e14', artist='Junior H', tour_name=None, venue='Germania Insurance Amphitheater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962088)),
#  NewConcert(id=None, uid='bf12ab06-c78c-4a21-94a5-5eb42a07e529', artist='Chris Stussy (18+ Event)', tour_name=None, venue='The Concourse Project', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 21, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962133)),
#  NewConcert(id=None, uid='eb33c5b9-d8b8-4283-b8b5-ebd31f0ba64b', artist='Royel Otis', tour_name=None, venue='Stubbs BarBQ', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962176)),
#  NewConcert(id=None, uid='5be4b766-e611-436e-8a41-a90306de8b07', artist='Lake Street Dive', tour_name=None, venue='Moody Amphitheater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962218)),
#  NewConcert(id=None, uid='c71841b6-36e4-4d8b-a1e8-52a2e634e0a0', artist='Stardew Valley - Symphony of Seasons', tour_name=None, venue='Austin City Limits Live at The Moody Theater', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962260)),
#  NewConcert(id=None, uid='40739699-bc4c-4352-8a11-09a9798d19e2', artist='Clay Walker', tour_name=None, venue="Johnny's Steaks and BBQ", location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 18, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962303)),
#  NewConcert(id=None, uid='acfe688c-ed62-4ae9-8e1a-804903cd0d52', artist='Raphael Saadiq', tour_name=None, venue='Paramount Theatre Austin', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962344)),
#  NewConcert(id=None, uid='031021c7-fd66-4e71-b502-74125ed9bfad', artist='Jeremy Zucker', tour_name=None, venue='Scoot Inn', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962385)),
#  NewConcert(id=None, uid='fb8603ae-6aef-4a8a-9e0f-44b474f6f62a', artist='Satin Jackets', tour_name=None, venue='Empire - Garage', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962428)),
#  NewConcert(id=None, uid='74ac6c3c-2bed-423c-87c9-03a519e85f06', artist='Zach Person', tour_name=None, venue='Stubbs BarBQ', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 22, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962485)),
#  NewConcert(id=None, uid='781515e3-5255-45fd-b716-494df834fe25', artist='SG Goodman (21+ Event)', tour_name=None, venue="Antone's - Austin", location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962527)),
#  NewConcert(id=None, uid='bbe3218d-db33-4c4d-9412-ce1f186d629c', artist='Soul Man Sam', tour_name=None, venue="Antone's - Austin", location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962568)),
#  NewConcert(id=None, uid='1f22efd7-40da-4098-953a-b18cc54ea3d8', artist='Scotty Alexander', tour_name=None, venue='Gruene Hall', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 21, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962609)),
#  NewConcert(id=None, uid='3e1f8cb2-c010-4ce1-bcb9-e8488a54c1fe', artist='Crypta', tour_name=None, venue='Come and Take It Live', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962650)),
#  NewConcert(id=None, uid='2fc67bc2-d4c6-46b6-81d5-2dbf36099079', artist='SKYROCKET!', tour_name=None, venue='3TEN Austin City Limits Live', location='Austin, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 39, 962691)),
#  NewConcert(id=None, uid='b7b5885a-2712-4ff8-b760-e7bf0bcd9e17', artist='Houston Livestock Show and Rodeo - Cody Johnson (Concert Only, No Houston Rodeo Performance)', tour_name=None, venue='NRG Stadium', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 3, 22, 23, 59), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 805562)),
#  NewConcert(id=None, uid='3f6d7566-952d-4c01-81fa-e92a808fc326', artist='Bring Me The Horizon', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 26, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 805635)),
#  NewConcert(id=None, uid='8b3b5096-7780-42a8-a847-b7cc4d94cf8a', artist='The Lumineers', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 10, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 805687)),
#  NewConcert(id=None, uid='ee306bf6-54a9-461d-8420-b4c5b72b3864', artist='Ludovico Einaudi', tour_name=None, venue='Smart Financial Centre', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 12, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 805732)),
#  NewConcert(id=None, uid='49481d13-7eb4-47c9-a850-531de0f55a32', artist='Keith Urban', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 11, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 805776)),
#  NewConcert(id=None, uid='07559cd6-4812-4886-a54e-6ab83ef0614b', artist='Pentatonix', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 12, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 805820)),
#  NewConcert(id=None, uid='7bf3f58d-c8be-404b-b460-1631645bcc91', artist='Maroon 5', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 11, 5, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 805863)),
#  NewConcert(id=None, uid='e1f7f255-f929-4a81-aa8f-ab34edcea594', artist='Ella Langley (Moved from House of Blues)', tour_name=None, venue='713 Music Hall', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 16, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 805909)),
#  NewConcert(id=None, uid='c5ebee67-471f-4123-9ebf-97fab372ae52', artist='Alice Cooper and Judas Priest', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 26, 18, 45), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 805954)),
#  NewConcert(id=None, uid='814d239b-87a7-4088-a43c-0af02e105e61', artist='Junior H', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 5, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 805999)),
#  NewConcert(id=None, uid='c8cafbb7-4392-42d4-8198-3aa91df6b0ea', artist='Whiskey Myers', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 27, 18, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806041)),
#  NewConcert(id=None, uid='96167fee-96fb-4775-b201-8f376000a1d0', artist='Fujii Kaze', tour_name=None, venue='Bayou Music Center', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 8, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806083)),
#  NewConcert(id=None, uid='53d4ded6-0b40-412c-a1da-ce278acae963', artist='For King And Country', tour_name=None, venue='Smart Financial Centre', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 12, 6, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806125)),
#  NewConcert(id=None, uid='f957dc62-4ec0-4dc6-94df-f99cd9889910', artist='Leon Thomas (Moved from House of Blues Houston)', tour_name=None, venue='Bayou Music Center', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 11, 4, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806166)),
#  NewConcert(id=None, uid='f2b8f686-61e7-43a9-8068-4aedf226ecd5', artist='Giveon', tour_name=None, venue='Smart Financial Centre', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 15, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806207)),
#  NewConcert(id=None, uid='79aede30-c966-4544-a797-430869c86656', artist='Crooner and The Cowboy - Leon Bridges and Charley Crockett', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806248)),
#  NewConcert(id=None, uid='88035ce2-61ca-474d-a27e-2c981e1ad884', artist='Lainey Wilson', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806290)),
#  NewConcert(id=None, uid='448cdbb7-b97a-4873-ad4a-db5e628a535a', artist='NBA YoungBoy', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 28, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806331)),
#  NewConcert(id=None, uid='72b1b8f3-fc30-426b-ad48-d3a9a6807e89', artist='Tate McRae', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 11, 1, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806375)),
#  NewConcert(id=None, uid='372d72c2-3599-4625-a7d2-0d3cdc64ea3e', artist='Ana Gabriel', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 27, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806419)),
#  NewConcert(id=None, uid='f67f7a5f-8f39-46a5-ae36-572a5a7b9a4e', artist='Laufey', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806460)),
#  NewConcert(id=None, uid='f84cd170-86f8-42fa-bc67-4eb2a95512cd', artist='Brandy and Monica', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 12, 7, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806502)),
#  NewConcert(id=None, uid='df3cc03b-d847-4f25-ae23-24fdeeae7f58', artist='Houston Livestock Show and Rodeo - Cody Johnson (Concert Only, No Houston Rodeo Performance)', tour_name=None, venue='NRG Stadium', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 3, 22, 23, 59), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806546)),
#  NewConcert(id=None, uid='dda92dc4-a004-4671-b704-52e98bf6c82e', artist='Jonas Brothers', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 19, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806591)),
#  NewConcert(id=None, uid='dc31051b-9f05-4e16-972e-4108b1412567', artist='Bring Me The Horizon', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 26, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806633)),
#  NewConcert(id=None, uid='8a6cfdf5-4159-4b8d-b183-49b04c54d638', artist='Junior H', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 4, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806675)),
#  NewConcert(id=None, uid='979b51ac-de40-421d-add8-50711880e38f', artist='The Lumineers', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 10, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806716)),
#  NewConcert(id=None, uid='0d23c493-45b4-4ada-8396-b544bbe7aa56', artist='SuicideBoys', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 10, 18, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806757)),
#  NewConcert(id=None, uid='678ab635-ff16-40b4-9ff2-5091ee2cb31d', artist='Katseye', tour_name=None, venue='Smart Financial Centre', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 11, 29, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806798)),
#  NewConcert(id=None, uid='68707832-bd88-4069-a314-0ab28c0a4646', artist='Ludovico Einaudi', tour_name=None, venue='Smart Financial Centre', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 12, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806840)),
#  NewConcert(id=None, uid='5030afd2-0eab-4a93-ab23-0e50b3766b9b', artist='Keith Urban', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 10, 11, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806883)),
#  NewConcert(id=None, uid='0671c6fc-398b-49ba-aff0-ce39b4df20a0', artist='Pentatonix', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 12, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806926)),
#  NewConcert(id=None, uid='9dabd025-87fb-4b76-b689-618276b46960', artist='Lainey Wilson', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 806969)),
#  NewConcert(id=None, uid='534a4bfb-1805-4108-a3b8-38a0417d5933', artist='Laufey', tour_name=None, venue='Toyota Center - TX', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807010)),
#  NewConcert(id=None, uid='b1ea8656-e867-4f49-b203-1da238e0ac99', artist='Carin Leon', tour_name=None, venue='Fort Bend EpiCenter', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 16, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807052)),
#  NewConcert(id=None, uid='4c524560-bfce-42c2-b9d1-069002bee790', artist='Crooner and The Cowboy - Leon Bridges and Charley Crockett', tour_name=None, venue='Cynthia Woods Mitchell Pavilion', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807098)),
#  NewConcert(id=None, uid='91687b46-74de-4709-b03b-53c5a0db89f5', artist='Wyatt Flores', tour_name=None, venue='713 Music Hall', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807139)),
#  NewConcert(id=None, uid='4c1283aa-4e85-426b-bf98-9dd2f8e894c7', artist='Lake Street Dive', tour_name=None, venue='713 Music Hall', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807182)),
#  NewConcert(id=None, uid='dc1dc2ec-3220-4bcd-ba25-353e34bfdc00', artist='Louie TheSinger', tour_name=None, venue='House of Blues Houston', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807226)),
#  NewConcert(id=None, uid='22178f6e-a97c-422c-9054-076c2a4310d4', artist='Pasadena Rodeo (Impostores De Nuevo Leon and Grupo Zenzio)', tour_name=None, venue='Pasadena Livestock Show and Rodeo Grounds', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 12, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807270)),
#  NewConcert(id=None, uid='5a1fabf5-9105-4749-9df5-cfa1351ea668', artist='Strings and Heart', tour_name=None, venue='The Bronze Peacock at House of Blues Houston', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807312)),
#  NewConcert(id=None, uid='73b2f4e5-7fd7-4a16-9150-aa8e96de5f68', artist='Bad Suns', tour_name=None, venue='White Oak Music Hall - Downstairs', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807354)),
#  NewConcert(id=None, uid='75be4e9b-33ca-4655-8584-8d1d9c96e3f3', artist='Toad the Wet Sprocket', tour_name=None, venue='House of Blues Houston', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807394)),
#  NewConcert(id=None, uid='528fea32-9ea4-4dbc-9779-39324204d4b1', artist='Beherit', tour_name=None, venue='White Oak Music Hall - Downstairs', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807438)),
#  NewConcert(id=None, uid='97c8c2ed-b74b-48f9-9e97-11ae9b862f42', artist='Pasadena Rodeo - 49 Winchester', tour_name=None, venue='Pasadena Livestock Show and Rodeo Grounds', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 17, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807482)),
#  NewConcert(id=None, uid='a825f1a2-5565-4b92-910a-8467a720dd9e', artist='Liam St John', tour_name=None, venue='Bad Astronaut Brewing Co', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807527)),
#  NewConcert(id=None, uid='eeb57870-15a3-4d25-8b3f-03ae97373a25', artist='Houston Symphony - Stravinskys Firebird', tour_name=None, venue='Jones Hall at Wortham Center', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 14, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807568)),
#  NewConcert(id=None, uid='7eed35ce-c014-4d36-96bf-cbafe728dd28', artist='Nitzer Ebb', tour_name=None, venue='Numbers', location='Houston, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 40, 807609)),
#  NewConcert(id=None, uid='a99e4181-dfff-4918-a92e-e9bc05075451', artist='Paul McCartney', tour_name=None, venue='Alamodome', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 25, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572276)),
#  NewConcert(id=None, uid='647b4729-78da-4955-9daa-d585001214c8', artist='Ella Langley', tour_name=None, venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 17, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572345)),
#  NewConcert(id=None, uid='1827ffed-67c1-4ef4-8959-e6a665df191b', artist='Jonas Brothers', tour_name=None, venue='Frost Bank Center', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 18, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572394)),
#  NewConcert(id=None, uid='50c86445-ffe7-4594-993f-5e282b081c71', artist='Brandon Lake', tour_name=None, venue='Frost Bank Center', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 4, 9, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572443)),
#  NewConcert(id=None, uid='3572e9df-2eb9-44a4-9dc5-0498a372458c', artist='Role Model', tour_name=None, venue='Aztec Theatre', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 2, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572486)),
#  NewConcert(id=None, uid='a779d350-ad5b-47b6-8098-c6c4c899e35f', artist='Cage The Elephant', tour_name=None, venue='Boeing Center at Tech Port', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 4, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572531)),
#  NewConcert(id=None, uid='d075d70e-9a03-47b6-a280-57e688395f59', artist='Air1 Worship Now - Phil Wickham, Charity Gayle, and Josh Baldwin', tour_name=None, venue='Freeman Coliseum', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 17, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572574)),
#  NewConcert(id=None, uid='058d97ba-c6ce-4b2d-ace4-4324c81fe6c6', artist='Twilight in Concert', tour_name=None, venue='Majestic Theatre San Antonio', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 12, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572624)),
#  NewConcert(id=None, uid='665878ef-7f24-452c-95e4-8777347655fe', artist='Tucker Wetmore (Rescheduled from 5/2)', tour_name=None, venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 26, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572667)),
#  NewConcert(id=None, uid='436f8d29-faa0-4116-b3b0-e19a9ce25cde', artist='Christian Nodal', tour_name=None, venue='Frost Bank Center', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 11, 23, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572709)),
#  NewConcert(id=None, uid='60fe0712-a4eb-49d8-986b-845bfdb1077c', artist='Midland', tour_name=None, venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 11, 8, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572751)),
#  NewConcert(id=None, uid='1a42a405-b1f1-4fc2-b638-ff6a252d86bd', artist='Randy Travis', tour_name=None, venue='Majestic Theatre San Antonio', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 3, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572792)),
#  NewConcert(id=None, uid='e1b89d82-dcdf-4d81-aea6-69474df84d00', artist='The Cult', tour_name=None, venue='Majestic Theatre San Antonio', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 21, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572834)),
#  NewConcert(id=None, uid='64432747-7e37-4f36-a18c-8ba7ec4ef9c2', artist='Rilo Kiley (21+ Event)', tour_name=None, venue='Aztec Theatre', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 8, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572876)),
#  NewConcert(id=None, uid='13055f25-fcd3-4b9f-a163-cb3e93df807c', artist='William Beckmann (18+ Event)', tour_name=None, venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572917)),
#  NewConcert(id=None, uid='50f1a9cb-e1f7-4fdd-a313-7210097921a0', artist='Michael Schenker', tour_name=None, venue='Tobin Center for the Performing Arts', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 10, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572958)),
#  NewConcert(id=None, uid='670412bf-8651-4983-9d83-c86f91f17cf0', artist='Chris Brown', tour_name=None, venue='Alamodome', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 27, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 572998)),
#  NewConcert(id=None, uid='b0f4b5bb-6f2b-4c4f-91ed-0c05057930bf', artist='Paul McCartney', tour_name=None, venue='Alamodome', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 25, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573039)),
#  NewConcert(id=None, uid='ba7e3319-c3b0-4f97-a79d-88dbe4cc4565', artist='NBA YoungBoy', tour_name=None, venue='Frost Bank Center', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 29, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573080)),
#  NewConcert(id=None, uid='44fac2d1-3964-487e-a6d9-d3f840bd3e5b', artist='Ella Langley', tour_name=None, venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 17, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573121)),
#  NewConcert(id=None, uid='53d172ad-c8d3-4398-93a4-f12e772e75a9', artist='Morrissey (Rescheduled from 5/8/2025)', tour_name=None, venue='Boeing Center at Tech Port', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 1, 10, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573162)),
#  NewConcert(id=None, uid='d853a7bd-db18-4508-be8e-f01b1d72635e', artist='Jonas Brothers', tour_name=None, venue='Frost Bank Center', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 18, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573203)),
#  NewConcert(id=None, uid='73f3ee41-627c-4ac7-a852-ab2b7331776e', artist='Brandon Lake', tour_name=None, venue='Frost Bank Center', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 4, 9, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573253)),
#  NewConcert(id=None, uid='56806e39-5cbc-40d6-9ce3-fd0bcadd9f04', artist='Role Model', tour_name=None, venue='Aztec Theatre', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 2, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573296)),
#  NewConcert(id=None, uid='f097252a-e9ef-4877-acf2-29863afbcc8e', artist='Cage The Elephant', tour_name=None, venue='Boeing Center at Tech Port', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 4, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573340)),
#  NewConcert(id=None, uid='213d147b-dbc0-45a4-8c0e-ed6d05e47b0c', artist='Air1 Worship Now - Phil Wickham, Charity Gayle, and Josh Baldwin', tour_name=None, venue='Freeman Coliseum', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 17, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573382)),
#  NewConcert(id=None, uid='2f6e5bc6-890a-42d0-a09d-210ef6dc8c91', artist='Twilight in Concert', tour_name=None, venue='Majestic Theatre San Antonio', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 12, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573423)),
#  NewConcert(id=None, uid='625f174d-0874-4a6a-b363-0fb3308353f5', artist='Tucker Wetmore (Rescheduled from 5/2)', tour_name=None, venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 26, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573464)),
#  NewConcert(id=None, uid='3a2e825f-37fc-4985-b5b5-0dec8c2e5d9d', artist='Ramon Ayala', tour_name=None, venue='Freeman Coliseum', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 10, 4, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573509)),
#  NewConcert(id=None, uid='a78b8f79-f579-4f27-900a-c187f57b8055', artist='Christian Nodal', tour_name=None, venue='Frost Bank Center', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 11, 23, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573550)),
#  NewConcert(id=None, uid='ace3884b-0172-449e-874d-bc55930eea0a', artist='San Antonio Stock Show and Rodeo - Miranda Lambert', tour_name=None, venue='Frost Bank Center', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 2, 18, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573591)),
#  NewConcert(id=None, uid='6342004b-4191-467b-8b92-7d5e2fab6068', artist='Midland', tour_name=None, venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 11, 8, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573632)),
#  NewConcert(id=None, uid='a884f99e-9d5a-4b11-8746-a1e904620c06', artist='William Beckmann (18+ Event)', tour_name=None, venue='John T. Floores Country Store - Outdoor', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573673)),
#  NewConcert(id=None, uid='de46f838-72e2-46d5-b968-8222179551ff', artist='Molotov', tour_name=None, venue='Aztec Theatre', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573714)),
#  NewConcert(id=None, uid='13574e13-5d39-4c46-addd-7689b4046989', artist='Suzy Bogguss', tour_name=None, venue='Cailloux Theater', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573755)),
#  NewConcert(id=None, uid='4cf73422-9e81-45ab-9760-ecab3a9dd086', artist='Louie TheSinger', tour_name=None, venue='Aztec Theatre', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573796)),
#  NewConcert(id=None, uid='4e08d562-fa73-41bc-b05b-c3254b12fe8f', artist='Mon Rovia', tour_name=None, venue='Stable Hall', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573836)),
#  NewConcert(id=None, uid='518d8443-bc59-4bed-a35a-ebd95b399ca3', artist='Terri Clark', tour_name=None, venue='Tobin Center for the Performing Arts', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573876)),
#  NewConcert(id=None, uid='d32153b1-5e23-4da6-9322-fdf67598e433', artist='Kota The Friend', tour_name=None, venue='Paper Tiger', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573927)),
#  NewConcert(id=None, uid='10157983-fbe4-400b-a823-a5bc8d4842b2', artist='Asleep at the Wheel', tour_name=None, venue='Luckenbach Texas', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 573970)),
#  NewConcert(id=None, uid='8ed71618-64c2-49ed-8a8e-7bf1b5b0814c', artist='Majesty of Rock - A Journey/Styx Tribute Experience', tour_name=None, venue='Charline McCombs Empire Theatre', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 574012)),
#  NewConcert(id=None, uid='9e89c806-c62e-4893-adc9-e241e5556c0c', artist='Scotty Alexander', tour_name=None, venue='Gruene Hall', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 21, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 574054)),
#  NewConcert(id=None, uid='0951fa8b-0932-4bd7-87f9-43f41d6ef12b', artist='VHT - Van Halen Tribute', tour_name=None, venue='Sams Burger Joint', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 574095)),
#  NewConcert(id=None, uid='978ecfcb-5022-469f-a1f0-f636ce7260c8', artist='Bad Habit (18+ Event)', tour_name=None, venue='Sams Burger Joint', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 574135)),
#  NewConcert(id=None, uid='f6470aa3-1b07-4156-82e4-35f41f4e6e80', artist='Donella Drive', tour_name=None, venue='Paper Tiger', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 574176)),
#  NewConcert(id=None, uid='4a40326a-64f2-4e87-8b60-3caadb3ac437', artist='Strings And Heart', tour_name=None, venue='Paper Tiger', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 574216)),
#  NewConcert(id=None, uid='8c0bbd01-5070-4055-a120-f21c026d068b', artist='Emery', tour_name=None, venue='The Rock Box', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 18, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 574257)),
#  NewConcert(id=None, uid='e9cda8d1-3fd9-463a-920a-1836205584b6', artist='Caleb Young (18+ Event)', tour_name=None, venue='Cheatham Street Warehouse', location='San Antonio, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 41, 574297)),
#  NewConcert(id=None, uid='0bc42f00-fbaa-44ce-aa37-e68cf733bdf5', artist='Dua Lipa', tour_name=None, venue='American Airlines Center - TX', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 30, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 285889)),
#  NewConcert(id=None, uid='93de69a8-747c-49a6-af48-21dca96c4c34', artist='Ella Langley (18+ Event)', tour_name=None, venue='Billy Bobs', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 10, 18, 22, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 285962)),
#  NewConcert(id=None, uid='5e8fb5bb-8860-45e7-b24a-5ba2f576285e', artist='Bring Me The Horizon', tour_name=None, venue='American Airlines Center - TX', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 27, 18, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 286013)),
#  NewConcert(id=None, uid='4d471c25-2ee8-4fdf-af0a-844c86d05167', artist='The Red Clay Strays', tour_name=None, venue='Pavilion at Toyota Music Factory', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 25, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 286058)),
#  NewConcert(id=None, uid='d2183fdc-1230-4f68-aaa4-9d7f580542c7', artist='Sombr (Moved from Cambridge Room at House of Blues Dallas, South Side Music Hall)', tour_name=None, venue='Credit Union of Texas Event Center', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 10, 17, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 286113)),
#  NewConcert(id=None, uid='93c4768f-25ea-4e7e-9b2a-429380d3a242', artist='Keith Urban', tour_name=None, venue='Dickies Arena', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 10, 9, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 286158)),
#  NewConcert(id=None, uid='46dd4377-ee9a-4cac-8410-28d2cb2d83e8', artist='Dom Dolla (18+ Event)', tour_name=None, venue='Dos Equis Pavilion', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 11, 1, 18, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 286202)),
#  NewConcert(id=None, uid='c0dbb353-ec34-4e6f-b4ef-e47f8dc34525', artist='Maroon 5', tour_name=None, venue='American Airlines Center - TX', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 11, 7, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 286245)),
#  NewConcert(id=None, uid='f1c0d7ae-689a-4efc-8ad6-9178ee7386c5', artist='The World of Hans Zimmer', tour_name=None, venue='Dickies Arena', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 29, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 286288)),
#  NewConcert(id=None, uid='7e8d1e9a-a8e3-4bee-b4b9-20a7f14590fd', artist='T-Pain', tour_name=None, venue='Pavilion at Toyota Music Factory', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 10, 22, 19, 45), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 286329)),
#  NewConcert(id=None, uid='a494e569-688f-4263-95ef-c79f4ff74d79', artist='Junior H', tour_name=None, venue='Dos Equis Pavilion', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 10, 26, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 286371)),
# ...
#  NewConcert(id=None, uid='f1418e3e-c89c-4991-8d77-fe7d54807d90', artist='Keith Urban', tour_name=None, venue='Dickies Arena', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 10, 9, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287300)),
#  NewConcert(id=None, uid='561eaee2-91f4-4497-8003-e6b327008dbe', artist='Mana', tour_name=None, venue='American Airlines Center - TX', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 11, 1, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287341)),
#  NewConcert(id=None, uid='595dfce8-0bd1-4460-a38e-c7c7ac5eb86d', artist='Benson Boone', tour_name=None, venue='Dickies Arena', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287382)),
#  NewConcert(id=None, uid='c2672b5a-59d4-4a5f-98aa-c7952880901d', artist='Bunt (18+ Event)', tour_name=None, venue='SILO Dallas', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 21, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287423)),
#  NewConcert(id=None, uid='8f1ac508-0213-4475-b896-4bee930e3974', artist='Above and Beyond', tour_name=None, venue='Dos Equis Pavilion', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287464)),
#  NewConcert(id=None, uid='b563a4b8-751c-4a11-992c-edbf471b4270', artist='Stardew Valley - Symphony of Seasons', tour_name=None, venue='Texas Trust CU Theatre at Grand Prairie', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287504)),
#  NewConcert(id=None, uid='350ca045-8c25-4a95-be73-377fe66381ff', artist='Charles Wesley Godwin (18+ Event)', tour_name=None, venue='Billy Bobs', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 22, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287546)),
#  NewConcert(id=None, uid='a06f8e6f-3aeb-4fe1-85f5-e9f24504dafc', artist='Destin Conrad', tour_name=None, venue='House of Blues Dallas', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287587)),
#  NewConcert(id=None, uid='0c42643c-c033-4cac-9041-be5efdb04511', artist='Ben Folds', tour_name=None, venue='Tannahills Tavern and Music Hall', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287628)),
#  NewConcert(id=None, uid='2755aedb-443b-49c7-b33b-00a35848553f', artist='Mon Rovia', tour_name=None, venue='The Kessler Theater', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287720)),
#  NewConcert(id=None, uid='b64c0434-d863-47e4-a3d6-2af1f4d4d3c9', artist='Randy Rogers Band', tour_name=None, venue='Longhorn Backyard Amphitheater', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287786)),
#  NewConcert(id=None, uid='35aaacb3-f6af-4bce-81c8-95030398a0d3', artist="Guns 4 Roses - Guns N' Roses Tribute", tour_name=None, venue='Lava Cantina The Colony', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287837)),
#  NewConcert(id=None, uid='98e4233b-cae3-4e00-886e-c6a41d7f4e98', artist='Kota The Friend', tour_name=None, venue='Trees', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287881)),
#  NewConcert(id=None, uid='8918fc91-7a19-4bbc-9d4e-db7c50f93490', artist='The Spill Canvas and Mae', tour_name=None, venue='Granada Theater Dallas', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287925)),
#  NewConcert(id=None, uid='669b2ab1-12cf-48ee-ad61-130a03211250', artist='Gannon Fremin', tour_name=None, venue='Tannahills Tavern and Music Hall', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 21, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 287967)),
#  NewConcert(id=None, uid='457c7c34-2632-47dd-9475-434e49d8adea', artist='Anamanaguchi', tour_name=None, venue='The Studio at The Bomb Factory', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 288010)),
#  NewConcert(id=None, uid='e79eefbd-fb42-455f-a698-e3b649354762', artist='Andy and Shani', tour_name=None, venue='Eisemann Center', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 288053)),
#  NewConcert(id=None, uid='ac65bb91-8cac-40cd-a6f2-88d00dd79c7a', artist='Ewan McVicar (21+ Event)', tour_name=None, venue='Itll Do Club', location='Dallas, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 21, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 288095)),
#  NewConcert(id=None, uid='d6515969-a1d6-4149-9938-484edfafd7d0', artist='Alejandro Fernandez (Rescheduled from 9/7)', tour_name=None, venue='Don Haskins Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 19, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 883495)),
#  NewConcert(id=None, uid='136b04e2-ad60-4180-b281-0f0df226f093', artist='Christian Nodal', tour_name=None, venue='Don Haskins Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 11, 16, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 883565)),
#  NewConcert(id=None, uid='9f050fc0-a062-4282-8ccb-34baa160f399', artist='Banda Ms', tour_name=None, venue='Don Haskins Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 25, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 883615)),
#  NewConcert(id=None, uid='d466c23b-24c8-4467-a611-71ea0bb1b6d8', artist='Eden Munoz', tour_name=None, venue='Abraham Chavez Theatre', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 11, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 883660)),
#  NewConcert(id=None, uid='e1790c07-5044-45cc-bc54-9a8c11fd6136', artist='KLAQ Rocks the Park with Scott Stapp', tour_name=None, venue='Southwest University Park', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 4, 23, 59), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 883758)),
#  NewConcert(id=None, uid='0493a7f1-4ddb-4922-8e4f-c1d29becf5cb', artist='Chris Lake', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 12, 12, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 883804)),
#  NewConcert(id=None, uid='c0b6b992-3b62-4385-8b99-8bfc628c3c7d', artist='Heart - Rock Band', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 3, 6, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 883846)),
#  NewConcert(id=None, uid='1e6a44ee-6c55-4fd4-b58c-d2264eea41f6', artist='ROZ', tour_name=None, venue='Lowbrow Palace', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 10, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 883889)),
#  NewConcert(id=None, uid='335efadf-3f7b-4328-9b44-d2741974a744', artist='Brincos Dieras and Kevyn Contreras', tour_name=None, venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 883931)),
#  NewConcert(id=None, uid='b542ae11-235c-4557-a706-bcf2814b8fb9', artist='Intocable', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 11, 8, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 883978)),
#  NewConcert(id=None, uid='c6f0f69f-d0b4-41d6-99b3-a1dcf6113e49', artist='Jesse and Joy', tour_name=None, venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 1, 30, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884020)),
#  NewConcert(id=None, uid='fe29eba9-fee1-4e0f-8742-91bf72cb9da9', artist='Midland', tour_name=None, venue='Cowtown Outdoor Venue', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 2, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884061)),
#  NewConcert(id=None, uid='f74b3682-dea1-4d6e-9906-75a7b5e9e724', artist='Shoreline Mafia (13+ Event)', tour_name=None, venue='11:11', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 9, 29, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884109)),
#  NewConcert(id=None, uid='fae98d23-aa3b-4a76-b31b-ad3b0c2003b4', artist='Clave Especial', tour_name=None, venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 9, 28, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884153)),
#  NewConcert(id=None, uid='a3f0eddf-e1f6-4574-b77a-690b6a52f196', artist='Xavi', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 11, 20, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884196)),
#  NewConcert(id=None, uid='70907110-4e38-4f86-b793-32dfe198d1f1', artist='Way Out West Music Festival', tour_name=None, venue='El Paso Convention Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 9, 27, 17, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884237)),
#  NewConcert(id=None, uid='50b03eaa-c55e-42c7-98fe-fb23ba984329', artist='The Strokes', tour_name=None, venue='Abraham Chavez Theatre', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 1, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884278)),
#  NewConcert(id=None, uid='f442c3c2-ea9a-430f-8c93-0fb1e29166a6', artist='Alejandro Fernandez (Rescheduled from 9/7)', tour_name=None, venue='Don Haskins Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 19, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884319)),
#  NewConcert(id=None, uid='834b1a77-eb4b-468c-9c38-727aa34a4a11', artist='Miguel Bose', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 17, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884360)),
#  NewConcert(id=None, uid='702a14e4-93b4-4718-92c6-02eb83a537bf', artist='Christian Nodal', tour_name=None, venue='Don Haskins Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 11, 16, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884401)),
#  NewConcert(id=None, uid='6b6241a5-5348-4afc-8cca-49bc90b2d54c', artist='Banda Ms', tour_name=None, venue='Don Haskins Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 25, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884441)),
#  NewConcert(id=None, uid='2982a032-cfb1-4e9e-9927-ef56042dad51', artist='Eden Munoz', tour_name=None, venue='Abraham Chavez Theatre', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 11, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884482)),
#  NewConcert(id=None, uid='68afd092-9374-428e-b55b-ff6043e70c0b', artist='Chelo - El Adios de Una Grande (Rescheduled from 6/28)', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 11, 22, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884524)),
#  NewConcert(id=None, uid='55d20c2e-0373-40b9-9b51-78264f08d8ee', artist='KLAQ Rocks the Park with Scott Stapp', tour_name=None, venue='Southwest University Park', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 4, 23, 59), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884624)),
#  NewConcert(id=None, uid='d2df5055-0368-4e13-8724-42552ef15e41', artist='Chris Lake', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 12, 12, 19, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884667)),
#  NewConcert(id=None, uid='f190d127-6fac-4816-8e02-163e9777067c', artist='Heart - Rock Band', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 3, 6, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884709)),
#  NewConcert(id=None, uid='c97e92ce-3747-45af-b46b-9f0448a9a861', artist='ROZ', tour_name=None, venue='Lowbrow Palace', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 10, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884750)),
#  NewConcert(id=None, uid='341e64a0-79bd-4f8d-b13a-daabce6cecdf', artist='Amanda Miguel', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 11, 21, 20, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884791)),
#  NewConcert(id=None, uid='6c285bf2-ccdd-4979-8326-98826d30a581', artist='Marisela', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 10, 18, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884831)),
#  NewConcert(id=None, uid='07a3b178-e102-4286-b538-fe577cf0e715', artist='Brincos Dieras and Kevyn Contreras', tour_name=None, venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884873)),
#  NewConcert(id=None, uid='23224cb7-cd75-4e39-9e69-6e050b405cc7', artist='Intocable', tour_name=None, venue='El Paso County Coliseum', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 11, 8, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884914)),
#  NewConcert(id=None, uid='63185a51-e0a8-43d5-a8ed-77cd0e4b411d', artist='Jesse and Joy', tour_name=None, venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 1, 30, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 884965)),
#  NewConcert(id=None, uid='ca87d26e-2ed4-4845-8a88-c9f07a3c79c3', artist='Brincos Dieras and Kevyn Contreras', tour_name=None, venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 9, 21, 20, 0), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 885006)),
#  NewConcert(id=None, uid='e7d52168-5b99-4d74-91db-4e4f7ab78729', artist='El Paso Symphony Orchestra - Van Cliburn Gold with Aristo Sham', tour_name=None, venue='The Plaza Theatre Performing Arts Center', location='El Paso, TX, USA', concert_datetime=datetime.datetime(2025, 9, 20, 19, 30), status=1, update_datetime=datetime.datetime(2025, 9, 20, 7, 38, 42, 885047))]

# %%
import os
from dotenv import load_dotenv
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# get password and uri for database connection
load_dotenv()
db_password = os.getenv('MONGO_PASSWORD')
uri = os.getenv('DATABASE_URI').replace('db_password', db_password)

# create client and connect to server
client = MongoClient(uri, server_api=ServerApi('1'))

# ping for confirmation and update databases
db = client['bigcat']
for concert in concert_data:
    db['concert'].insert_one(concert.__dict__)

print('Done!')
# Out:
# Done!

# %%
pipeline = [
    {
        '$group': {
            '_id': {'artist': '$artist', 'tour_name': '$tour_name', 'venue': '$venue', 'location': '$location', 'datetime': '$datetime', 'status': '$status'},
            'duplicate_ids': {'$push': '$uid'},
            'count': {'$sum': 1}
        }
    },
    {
        '$match': {
            'count': {'$gt': 1}
        }
    }
]

duplicates = list(db['concert'].aggregate(pipeline))
print(f'{len(duplicates)} duplicates found.')

counter = 0

for doc in duplicates:
        ids_to_remove = doc['duplicate_ids'][1:]  # Keep the first, remove the rest
        if ids_to_remove:
            db['concert'].delete_many({'uid': {'$in': ids_to_remove}})
        counter += 1

print(f"{counter} duplicate documents removed.")
# Out:
# 98 duplicates found.
# 98 duplicate documents removed.

# %%
set([concert.venue for concert in concert_data if concert.location == 'Austin, TX, USA'])

# moody@admin.bigcat.com
# antones@admin.bigcat.com
# germania@admin.bigcat.com
# paramount@admin.bigcat.com
# Out:
# {'3TEN Austin City Limits Live',
#  "Antone's - Austin",
#  'Austin City Limits Live at The Moody Theater',
#  'Come and Take It Live',
#  'Empire - Garage',
#  'Germania Insurance Amphitheater',
#  'Gruene Hall',
#  "Johnny's Steaks and BBQ",
#  'Moody Amphitheater',
#  'Moody Center ATX',
#  'Paramount Theatre Austin',
#  'Scoot Inn',
#  'Stubbs BarBQ',
#  'The Concourse Project',
#  'Zilker Park'}
